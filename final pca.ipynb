# %%
import os

dataset_dir = r"C:\Users\ACER\Pca_model\Dataset\Augmented"
contents = os.listdir(dataset_dir)
print(contents)
# Out:
# ['Bacterial Spot', 'Early Blight', 'Healthy', 'Leaf Mold', 'Yellow Leaf Curl Virus']

# %%
def loadImages(data_dir):
  data = {}
  for c in ['Bacterial Spot', 'Early Blight', 'Healthy', 'Leaf Mold', 'Yellow Leaf Curl Virus']:
    data[c] = []
    if c == 'Bacterial Spot':
      label = 0
    elif c == 'Early Blight':
      label = 1
    elif c == 'Healthy':
      label = 2
    elif c == 'Leaf Mold':
      label = 3
    elif c == 'Yellow Leaf Curl Virus':
      label = 4   

    files = os.listdir(data_dir + '/' + c)
    files = files[0:3000] # Maximum number objects for each class

    print("A sample object from {} class:".format(c))
    plt.imshow(image.load_img(data_dir + '/' + c + '/' + files[4], target_size=(224, 224)))
    plt.show()

    for f_name in files:
      img_path = data_dir + '/' + c + '/' + f_name

      img = image.load_img(img_path, target_size=(224, 224))
      x = image.img_to_array(img)
      x = np.expand_dims(x, axis=0)
      x = preprocess_input(x)

      data[c].append([x, label])
  
  return data

# %%
import os
import numpy as np
from keras.utils import to_categorical
from keras.applications.densenet import DenseNet121
from keras.preprocessing import image
from keras.applications.densenet import preprocess_input, decode_predictions
from keras.models import Model
from keras.layers import Dense, GlobalAveragePooling2D, Dropout
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
data = loadImages(dataset_dir)
# Out:
# A sample object from Bacterial Spot class:
# A sample object from Early Blight class:
# A sample object from Healthy class:
# A sample object from Leaf Mold class:
# A sample object from Yellow Leaf Curl Virus class:

# %%
train_classObj1, test_classObj1 = train_test_split(data['Bacterial Spot'], test_size = 0.30)
train_classObj2, test_classObj2 = train_test_split(data['Early Blight'], test_size = 0.30)
train_classObj3, test_classObj3 = train_test_split(data['Healthy'], test_size = 0.30)
train_classObj4, test_classObj4 = train_test_split(data['Leaf Mold'], test_size = 0.30)
train_classObj5, test_classObj5 = train_test_split(data['Yellow Leaf Curl Virus'], test_size = 0.30)

# %%
print("The number of TRAIN objects in each class: ", len(train_classObj1))
print("The number of TEST objects in each class: ", len(test_classObj1))
# Out:
# The number of TRAIN objects in each class:  2100
# The number of TEST objects in each class:  900

# %%
train_objs = train_classObj1 + train_classObj2 + train_classObj3 + train_classObj4 + train_classObj5
test_objs = test_classObj1 + test_classObj2 + test_classObj3 + test_classObj4 + test_classObj5

# %%
train_data = [x[0] for x in train_objs]
train_label = [y[1] for y in train_objs]

test_data = [x[0] for x in test_objs]
test_label = [y[1] for y in test_objs]

# %%
X_train = np.array(train_data)
X_test = np.array(test_data)

# %%
train_data = np.squeeze(X_train)
train_label = np.array(train_label)

test_data = np.squeeze(X_test)
test_label = np.array(test_label)

# %%
print("Input dimension: ", train_data.shape)
print("Input dimension: ", test_label.shape)
# Out:
# Input dimension:  (10500, 224, 224, 3)
# Input dimension:  (4500,)

# %%
# Assuming your original labels are in train_label and test_label
num_classes = 5  # Total number of classes in your dataset
train_label_one_hot = to_categorical(train_label, num_classes=num_classes)
test_label_one_hot = to_categorical(test_label, num_classes=num_classes)

# Print the shapes of the one-hot encoded labels
print("One-hot encoded training label dimension: ", train_label_one_hot.shape)
print("One-hot encoded test label dimension: ", test_label_one_hot.shape)
# Out:
# One-hot encoded training label dimension:  (10500, 5)
# One-hot encoded test label dimension:  (4500, 5)

# %%
X_train_reshaped = X_train.reshape(-1, 224, 224)
X_test_reshaped = X_test.reshape(-1, 224, 224)
print("Reshaped dimension: ", X_train_reshaped.shape)
print("Reshaped dimension: ", X_test_reshaped.shape)
# Out:
# Reshaped dimension:  (31500, 224, 224)
# Reshaped dimension:  (13500, 224, 224)

# %%
# Reshape each image into a 1D array
X_train_flat = X_train.reshape(train_data.shape[0], -1)

# Verify the new shape
print("New shape of X_train:", X_train_flat.shape)
# Out:
# New shape of X_train: (10500, 150528)

# %%
from sklearn.decomposition import PCA

# Apply PCA for feature extraction
pca = PCA(n_components=100)  # Reduce to 50 principal components
X_train_pca = pca.fit_transform(X_train_flat)

# Verify the shape of the transformed data
print("Shape of X_train_pca:", X_train_pca.shape)
# Out:
# Shape of X_train_pca: (10500, 100)

# %%
# Extract features using PCA
training_feature = X_train_pca

# Similarly for the test data
X_test_flat = X_test.reshape(test_data.shape[0], -1)
X_test_pca = pca.transform(X_test_flat)
test_feature = X_test_pca

# %%
training_feature = np.array(training_feature)
test_feature = np.array(test_feature)

# %%
print("Training feature dimension: ", training_feature.shape)
print("Test feature dimension: ", test_feature.shape)
# Out:
# Training feature dimension:  (10500, 100)
# Test feature dimension:  (4500, 100)

# %%
from sklearn.decomposition import PCA

# Perform PCA for 2D representations
pca_2D = PCA(n_components=2)
training_feature_pca_2D = pca_2D.fit_transform(training_feature)
test_feature_pca_2D = pca_2D.fit_transform(test_feature)

# %%
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(1, 1, 1)
colors = ['r', 'g', 'b', 'c', 'm', 'y', 'k', 'orange', 'purple', 'brown'] # You can extend this list with more colors if needed
markers = ['o', 'P', 'v', '^', 's', 'D', 'X', '*', 'h', '<'] # You can extend this list with more markers if needed
classes = np.sort(np.unique(train_label))
labels = ['Bacterial Spot', 'Early Blight', 'Healthy', 'Leaf Mold', 'Yellow Leaf Curl Virus']

for class_ix, marker, color, label in zip(classes, markers[:len(classes)], colors[:len(classes)], labels[:len(classes)]):
    class_indices = np.where(train_label == class_ix)
    ax.scatter(training_feature_pca_2D[class_indices, 0],
               training_feature_pca_2D[class_indices, 1],
               marker=marker, color=color,
               linewidth=1, alpha=0.9, label=label)
# Get explained variance from PCA
explained_variance = pca.explained_variance_ratio_

ax.legend(loc='best')  
plt.xlabel(f'First principal component (EV: {explained_variance[0]*100:.2f}%)')
plt.ylabel(f'Second Principal Component (EV: {explained_variance[1]*100:.2f}%)')
plt.title("2 component PCA with Explained Variance")
plt.show()

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
# Train a classifier (SVM used here as an example)
clf = SVC()
clf.fit(training_feature, train_label)

# Evaluate the model on the testing set
y_pred = clf.predict(test_feature)
accuracy = accuracy_score(test_label, y_pred)
print("Test Accuracy:{:.2f}".format(accuracy*100))
# Out:
# Test Accuracy:95.24

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.regularizers import l2

training_features = (training_feature - np.mean(training_feature, axis=0)) / np.std(training_feature, axis=0)
test_features = (test_feature - np.mean(test_feature, axis=0)) / np.std(test_feature, axis=0)

n_components = 100 
# Build an enhanced neural network to use PCA features
model = Sequential()
model.add(Dense(1024, activation='relu', input_shape=(n_components,), kernel_regularizer=l2(0.001)))
model.add(Dropout(0.5))
model.add(Dense(512, activation='relu', kernel_regularizer=l2(0.001)))
model.add(Dropout(0.5))
model.add(Dense(256, activation='relu', kernel_regularizer=l2(0.001)))
model.add(Dropout(0.5))
model.add(Dense(128, activation='relu', kernel_regularizer=l2(0.001)))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu', kernel_regularizer=l2(0.001)))
model.add(Dropout(0.5))
model.add(Dense(32, activation='relu', kernel_regularizer=l2(0.001)))
model.add(Dropout(0.5))
model.add(Dense(5, activation='softmax'))

# Compile the model with a lower learning rate and use a learning rate scheduler
optimizer = Adam(learning_rate=0.001)
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# Learning rate reduction
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3, min_lr=0.00001)

# Train the model
history = model.fit(training_features, train_label_one_hot, epochs=100, batch_size=64, validation_data=(test_features, test_label_one_hot), callbacks=[reduce_lr])

# Evaluate the model
test_loss, test_acc = model.evaluate(test_features, test_label_one_hot)
print("Test Accuracy with Enhanced Dense Neural Network and PCA:", test_acc)
# Out:
# Epoch 1/100
# 165/165 [==============================] - 10s 35ms/step - loss: 2.9540 - accuracy: 0.2389 - val_loss: 2.7120 - val_accuracy: 0.4478 - lr: 0.0010
# Epoch 2/100
# 165/165 [==============================] - 6s 35ms/step - loss: 2.3721 - accuracy: 0.3914 - val_loss: 1.8479 - val_accuracy: 0.5520 - lr: 0.0010
# Epoch 3/100
# 165/165 [==============================] - 6s 36ms/step - loss: 1.6257 - accuracy: 0.6946 - val_loss: 1.2597 - val_accuracy: 0.8624 - lr: 0.0010
# Epoch 4/100
# 165/165 [==============================] - 5s 32ms/step - loss: 1.2028 - accuracy: 0.8310 - val_loss: 0.9379 - val_accuracy: 0.8864 - lr: 0.0010
# Epoch 5/100
# 165/165 [==============================] - 5s 31ms/step - loss: 0.9854 - accuracy: 0.8718 - val_loss: 0.8431 - val_accuracy: 0.8971 - lr: 0.0010
# Epoch 6/100
# 165/165 [==============================] - 5s 31ms/step - loss: 0.8996 - accuracy: 0.8834 - val_loss: 0.7843 - val_accuracy: 0.9053 - lr: 0.0010
# Epoch 7/100
# 165/165 [==============================] - 5s 33ms/step - loss: 0.8134 - accuracy: 0.9010 - val_loss: 0.7246 - val_accuracy: 0.9129 - lr: 0.0010
# Epoch 8/100
# 165/165 [==============================] - 5s 30ms/step - loss: 0.7208 - accuracy: 0.9144 - val_loss: 0.6912 - val_accuracy: 0.9207 - lr: 0.0010
# Epoch 9/100
# 165/165 [==============================] - 5s 31ms/step - loss: 0.7125 - accuracy: 0.9127 - val_loss: 0.6758 - val_accuracy: 0.9111 - lr: 0.0010
# Epoch 10/100
# 165/165 [==============================] - 5s 31ms/step - loss: 0.6688 - accuracy: 0.9224 - val_loss: 0.6545 - val_accuracy: 0.9224 - lr: 0.0010
# Epoch 11/100
# 165/165 [==============================] - 7s 44ms/step - loss: 0.6476 - accuracy: 0.9295 - val_loss: 0.6160 - val_accuracy: 0.9269 - lr: 0.0010
# Epoch 12/100
# 165/165 [==============================] - 5s 30ms/step - loss: 0.6321 - accuracy: 0.9325 - val_loss: 0.6036 - val_accuracy: 0.9313 - lr: 0.0010
# Epoch 13/100
# 165/165 [==============================] - 5s 31ms/step - loss: 0.5980 - accuracy: 0.9383 - val_loss: 0.6016 - val_accuracy: 0.9304 - lr: 0.0010
# Epoch 14/100
# 165/165 [==============================] - 5s 30ms/step - loss: 0.6009 - accuracy: 0.9409 - val_loss: 0.5918 - val_accuracy: 0.9356 - lr: 0.0010
# Epoch 15/100
# 165/165 [==============================] - 5s 29ms/step - loss: 0.6056 - accuracy: 0.9350 - val_loss: 0.5892 - val_accuracy: 0.9364 - lr: 0.0010
# Epoch 16/100
# 165/165 [==============================] - 5s 31ms/step - loss: 0.5579 - accuracy: 0.9487 - val_loss: 0.5922 - val_accuracy: 0.9260 - lr: 0.0010
# Epoch 17/100
# 165/165 [==============================] - 5s 31ms/step - loss: 0.5605 - accuracy: 0.9483 - val_loss: 0.5754 - val_accuracy: 0.9371 - lr: 0.0010
# Epoch 18/100
# 165/165 [==============================] - 5s 29ms/step - loss: 0.5351 - accuracy: 0.9511 - val_loss: 0.5773 - val_accuracy: 0.9400 - lr: 0.0010
# Epoch 19/100
# 165/165 [==============================] - 5s 31ms/step - loss: 0.5297 - accuracy: 0.9528 - val_loss: 0.5871 - val_accuracy: 0.9287 - lr: 0.0010
# Epoch 20/100
# 165/165 [==============================] - 6s 36ms/step - loss: 0.5396 - accuracy: 0.9526 - val_loss: 0.5733 - val_accuracy: 0.9331 - lr: 0.0010
# Epoch 21/100
# 165/165 [==============================] - 5s 29ms/step - loss: 0.5461 - accuracy: 0.9517 - val_loss: 0.5776 - val_accuracy: 0.9369 - lr: 0.0010
# Epoch 22/100
# 165/165 [==============================] - 5s 31ms/step - loss: 0.5174 - accuracy: 0.9563 - val_loss: 0.5729 - val_accuracy: 0.9344 - lr: 0.0010
# Epoch 23/100
# 165/165 [==============================] - 5s 31ms/step - loss: 0.5177 - accuracy: 0.9539 - val_loss: 0.5667 - val_accuracy: 0.9347 - lr: 0.0010
# Epoch 24/100
# 165/165 [==============================] - 5s 29ms/step - loss: 0.5068 - accuracy: 0.9579 - val_loss: 0.5850 - val_accuracy: 0.9340 - lr: 0.0010
# Epoch 25/100
# 165/165 [==============================] - 5s 29ms/step - loss: 0.5221 - accuracy: 0.9570 - val_loss: 0.6030 - val_accuracy: 0.9349 - lr: 0.0010
# Epoch 26/100
# 165/165 [==============================] - 5s 33ms/step - loss: 0.5211 - accuracy: 0.9589 - val_loss: 0.5762 - val_accuracy: 0.9396 - lr: 0.0010
# Epoch 27/100
# 165/165 [==============================] - 5s 31ms/step - loss: 0.4711 - accuracy: 0.9689 - val_loss: 0.5611 - val_accuracy: 0.9427 - lr: 2.0000e-04
# Epoch 28/100
# 165/165 [==============================] - 5s 30ms/step - loss: 0.4562 - accuracy: 0.9743 - val_loss: 0.5489 - val_accuracy: 0.9431 - lr: 2.0000e-04
# Epoch 29/100
# 165/165 [==============================] - 5s 30ms/step - loss: 0.4252 - accuracy: 0.9780 - val_loss: 0.5455 - val_accuracy: 0.9464 - lr: 2.0000e-04
# Epoch 30/100
# 165/165 [==============================] - 5s 32ms/step - loss: 0.4064 - accuracy: 0.9814 - val_loss: 0.5434 - val_accuracy: 0.9464 - lr: 2.0000e-04
# Epoch 31/100
# 165/165 [==============================] - 5s 30ms/step - loss: 0.3991 - accuracy: 0.9805 - val_loss: 0.5341 - val_accuracy: 0.9462 - lr: 2.0000e-04
# Epoch 32/100
# 165/165 [==============================] - 5s 32ms/step - loss: 0.3807 - accuracy: 0.9838 - val_loss: 0.5368 - val_accuracy: 0.9464 - lr: 2.0000e-04
# Epoch 33/100
# 165/165 [==============================] - 5s 30ms/step - loss: 0.3779 - accuracy: 0.9819 - val_loss: 0.5341 - val_accuracy: 0.9460 - lr: 2.0000e-04
# Epoch 34/100
# 165/165 [==============================] - 5s 32ms/step - loss: 0.3685 - accuracy: 0.9825 - val_loss: 0.5276 - val_accuracy: 0.9471 - lr: 2.0000e-04
# Epoch 35/100
# 165/165 [==============================] - 6s 34ms/step - loss: 0.3534 - accuracy: 0.9848 - val_loss: 0.5116 - val_accuracy: 0.9473 - lr: 2.0000e-04
# Epoch 36/100
# 165/165 [==============================] - 5s 32ms/step - loss: 0.3474 - accuracy: 0.9851 - val_loss: 0.5201 - val_accuracy: 0.9462 - lr: 2.0000e-04
# Epoch 37/100
# 165/165 [==============================] - 5s 31ms/step - loss: 0.3372 - accuracy: 0.9858 - val_loss: 0.5023 - val_accuracy: 0.9482 - lr: 2.0000e-04
# Epoch 38/100
# 165/165 [==============================] - 5s 30ms/step - loss: 0.3337 - accuracy: 0.9850 - val_loss: 0.5079 - val_accuracy: 0.9438 - lr: 2.0000e-04
# Epoch 39/100
# 165/165 [==============================] - 5s 30ms/step - loss: 0.3229 - accuracy: 0.9863 - val_loss: 0.5125 - val_accuracy: 0.9460 - lr: 2.0000e-04
# Epoch 40/100
# 165/165 [==============================] - 5s 29ms/step - loss: 0.3179 - accuracy: 0.9859 - val_loss: 0.5039 - val_accuracy: 0.9480 - lr: 2.0000e-04
# Epoch 41/100
# 165/165 [==============================] - 5s 30ms/step - loss: 0.3202 - accuracy: 0.9850 - val_loss: 0.4979 - val_accuracy: 0.9496 - lr: 4.0000e-05
# Epoch 42/100
# 165/165 [==============================] - 5s 30ms/step - loss: 0.3087 - accuracy: 0.9879 - val_loss: 0.4967 - val_accuracy: 0.9493 - lr: 4.0000e-05
# Epoch 43/100
# 165/165 [==============================] - 5s 29ms/step - loss: 0.3056 - accuracy: 0.9887 - val_loss: 0.4960 - val_accuracy: 0.9498 - lr: 4.0000e-05
# Epoch 44/100
# 165/165 [==============================] - 5s 29ms/step - loss: 0.3029 - accuracy: 0.9888 - val_loss: 0.4918 - val_accuracy: 0.9504 - lr: 4.0000e-05
# Epoch 45/100
# 165/165 [==============================] - 5s 28ms/step - loss: 0.2999 - accuracy: 0.9903 - val_loss: 0.4896 - val_accuracy: 0.9511 - lr: 4.0000e-05
# Epoch 46/100
# 165/165 [==============================] - 5s 29ms/step - loss: 0.2946 - accuracy: 0.9899 - val_loss: 0.4927 - val_accuracy: 0.9504 - lr: 4.0000e-05
# Epoch 47/100
# 165/165 [==============================] - 5s 29ms/step - loss: 0.2871 - accuracy: 0.9929 - val_loss: 0.4940 - val_accuracy: 0.9504 - lr: 4.0000e-05
# Epoch 48/100
# 165/165 [==============================] - 5s 30ms/step - loss: 0.2926 - accuracy: 0.9904 - val_loss: 0.4897 - val_accuracy: 0.9498 - lr: 4.0000e-05
# Epoch 49/100
# 165/165 [==============================] - 7s 42ms/step - loss: 0.2964 - accuracy: 0.9898 - val_loss: 0.4889 - val_accuracy: 0.9498 - lr: 1.0000e-05
# Epoch 50/100
# 165/165 [==============================] - 5s 29ms/step - loss: 0.2963 - accuracy: 0.9890 - val_loss: 0.4882 - val_accuracy: 0.9498 - lr: 1.0000e-05
# Epoch 51/100
# 165/165 [==============================] - 5s 31ms/step - loss: 0.2943 - accuracy: 0.9894 - val_loss: 0.4873 - val_accuracy: 0.9502 - lr: 1.0000e-05
# Epoch 52/100
# 165/165 [==============================] - 5s 31ms/step - loss: 0.3007 - accuracy: 0.9891 - val_loss: 0.4857 - val_accuracy: 0.9504 - lr: 1.0000e-05
# Epoch 53/100
# 165/165 [==============================] - 5s 30ms/step - loss: 0.2947 - accuracy: 0.9898 - val_loss: 0.4854 - val_accuracy: 0.9509 - lr: 1.0000e-05
# Epoch 54/100
# 165/165 [==============================] - 5s 30ms/step - loss: 0.2861 - accuracy: 0.9911 - val_loss: 0.4855 - val_accuracy: 0.9511 - lr: 1.0000e-05
# Epoch 55/100
# 165/165 [==============================] - 7s 45ms/step - loss: 0.2883 - accuracy: 0.9911 - val_loss: 0.4847 - val_accuracy: 0.9513 - lr: 1.0000e-05
# Epoch 56/100
# 165/165 [==============================] - 5s 29ms/step - loss: 0.2920 - accuracy: 0.9898 - val_loss: 0.4847 - val_accuracy: 0.9509 - lr: 1.0000e-05
# Epoch 57/100
# 165/165 [==============================] - 5s 30ms/step - loss: 0.2823 - accuracy: 0.9927 - val_loss: 0.4852 - val_accuracy: 0.9498 - lr: 1.0000e-05
# Epoch 58/100
# 165/165 [==============================] - 5s 29ms/step - loss: 0.2819 - accuracy: 0.9928 - val_loss: 0.4858 - val_accuracy: 0.9502 - lr: 1.0000e-05
# Epoch 59/100
# 165/165 [==============================] - 5s 29ms/step - loss: 0.2843 - accuracy: 0.9918 - val_loss: 0.4859 - val_accuracy: 0.9504 - lr: 1.0000e-05
# Epoch 60/100
# 165/165 [==============================] - 5s 31ms/step - loss: 0.2851 - accuracy: 0.9914 - val_loss: 0.4867 - val_accuracy: 0.9500 - lr: 1.0000e-05
# Epoch 61/100
# 165/165 [==============================] - 7s 45ms/step - loss: 0.2856 - accuracy: 0.9913 - val_loss: 0.4866 - val_accuracy: 0.9496 - lr: 1.0000e-05
# Epoch 62/100
# 165/165 [==============================] - 5s 30ms/step - loss: 0.2869 - accuracy: 0.9910 - val_loss: 0.4869 - val_accuracy: 0.9493 - lr: 1.0000e-05
# Epoch 63/100
# 165/165 [==============================] - 5s 31ms/step - loss: 0.2850 - accuracy: 0.9910 - val_loss: 0.4866 - val_accuracy: 0.9498 - lr: 1.0000e-05
# Epoch 64/100
# 165/165 [==============================] - 5s 29ms/step - loss: 0.2829 - accuracy: 0.9925 - val_loss: 0.4862 - val_accuracy: 0.9496 - lr: 1.0000e-05
# Epoch 65/100
# 165/165 [==============================] - 5s 29ms/step - loss: 0.2883 - accuracy: 0.9902 - val_loss: 0.4857 - val_accuracy: 0.9493 - lr: 1.0000e-05
# Epoch 66/100
# 165/165 [==============================] - 5s 29ms/step - loss: 0.2798 - accuracy: 0.9917 - val_loss: 0.4867 - val_accuracy: 0.9500 - lr: 1.0000e-05
# Epoch 67/100
# 165/165 [==============================] - 6s 34ms/step - loss: 0.2827 - accuracy: 0.9914 - val_loss: 0.4865 - val_accuracy: 0.9500 - lr: 1.0000e-05
# Epoch 68/100
# 165/165 [==============================] - 5s 29ms/step - loss: 0.2801 - accuracy: 0.9918 - val_loss: 0.4875 - val_accuracy: 0.9500 - lr: 1.0000e-05
# Epoch 69/100
# 165/165 [==============================] - 5s 30ms/step - loss: 0.2793 - accuracy: 0.9915 - val_loss: 0.4865 - val_accuracy: 0.9498 - lr: 1.0000e-05
# Epoch 70/100
# 165/165 [==============================] - 5s 30ms/step - loss: 0.2794 - accuracy: 0.9928 - val_loss: 0.4871 - val_accuracy: 0.9496 - lr: 1.0000e-05
# Epoch 71/100
# 165/165 [==============================] - 5s 29ms/step - loss: 0.2799 - accuracy: 0.9923 - val_loss: 0.4872 - val_accuracy: 0.9493 - lr: 1.0000e-05
# Epoch 72/100
# 165/165 [==============================] - 5s 31ms/step - loss: 0.2844 - accuracy: 0.9914 - val_loss: 0.4863 - val_accuracy: 0.9498 - lr: 1.0000e-05
# Epoch 73/100
# 165/165 [==============================] - 5s 29ms/step - loss: 0.2814 - accuracy: 0.9914 - val_loss: 0.4875 - val_accuracy: 0.9496 - lr: 1.0000e-05
# Epoch 74/100
# 165/165 [==============================] - 5s 29ms/step - loss: 0.2791 - accuracy: 0.9903 - val_loss: 0.4883 - val_accuracy: 0.9487 - lr: 1.0000e-05
# Epoch 75/100
# 165/165 [==============================] - 5s 31ms/step - loss: 0.2824 - accuracy: 0.9909 - val_loss: 0.4872 - val_accuracy: 0.9489 - lr: 1.0000e-05
# Epoch 76/100
# 165/165 [==============================] - 5s 31ms/step - loss: 0.2773 - accuracy: 0.9921 - val_loss: 0.4871 - val_accuracy: 0.9489 - lr: 1.0000e-05
# Epoch 77/100
# 165/165 [==============================] - 5s 29ms/step - loss: 0.2743 - accuracy: 0.9924 - val_loss: 0.4861 - val_accuracy: 0.9500 - lr: 1.0000e-05
# Epoch 78/100
# 165/165 [==============================] - 5s 30ms/step - loss: 0.2781 - accuracy: 0.9916 - val_loss: 0.4857 - val_accuracy: 0.9502 - lr: 1.0000e-05
# Epoch 79/100
# 165/165 [==============================] - 5s 31ms/step - loss: 0.2726 - accuracy: 0.9923 - val_loss: 0.4864 - val_accuracy: 0.9507 - lr: 1.0000e-05
# Epoch 80/100
# 165/165 [==============================] - 5s 31ms/step - loss: 0.2731 - accuracy: 0.9925 - val_loss: 0.4865 - val_accuracy: 0.9493 - lr: 1.0000e-05
# Epoch 81/100
# 165/165 [==============================] - 5s 30ms/step - loss: 0.2745 - accuracy: 0.9908 - val_loss: 0.4861 - val_accuracy: 0.9500 - lr: 1.0000e-05
# Epoch 82/100
# 165/165 [==============================] - 5s 31ms/step - loss: 0.2727 - accuracy: 0.9932 - val_loss: 0.4857 - val_accuracy: 0.9493 - lr: 1.0000e-05
# Epoch 83/100
# 165/165 [==============================] - 5s 31ms/step - loss: 0.2717 - accuracy: 0.9926 - val_loss: 0.4835 - val_accuracy: 0.9502 - lr: 1.0000e-05
# Epoch 84/100
# 165/165 [==============================] - 5s 30ms/step - loss: 0.2722 - accuracy: 0.9919 - val_loss: 0.4827 - val_accuracy: 0.9498 - lr: 1.0000e-05
# Epoch 85/100
# 165/165 [==============================] - 5s 31ms/step - loss: 0.2735 - accuracy: 0.9929 - val_loss: 0.4822 - val_accuracy: 0.9502 - lr: 1.0000e-05
# Epoch 86/100
# 165/165 [==============================] - 5s 30ms/step - loss: 0.2726 - accuracy: 0.9922 - val_loss: 0.4830 - val_accuracy: 0.9500 - lr: 1.0000e-05
# Epoch 87/100
# 165/165 [==============================] - 5s 30ms/step - loss: 0.2737 - accuracy: 0.9919 - val_loss: 0.4839 - val_accuracy: 0.9493 - lr: 1.0000e-05
# Epoch 88/100
# 165/165 [==============================] - 5s 32ms/step - loss: 0.2679 - accuracy: 0.9931 - val_loss: 0.4827 - val_accuracy: 0.9502 - lr: 1.0000e-05
# Epoch 89/100
# 165/165 [==============================] - 5s 31ms/step - loss: 0.2658 - accuracy: 0.9932 - val_loss: 0.4829 - val_accuracy: 0.9507 - lr: 1.0000e-05
# Epoch 90/100
# 165/165 [==============================] - 5s 30ms/step - loss: 0.2695 - accuracy: 0.9929 - val_loss: 0.4821 - val_accuracy: 0.9507 - lr: 1.0000e-05
# Epoch 91/100
# 165/165 [==============================] - 5s 30ms/step - loss: 0.2711 - accuracy: 0.9921 - val_loss: 0.4809 - val_accuracy: 0.9507 - lr: 1.0000e-05
# Epoch 92/100
# 165/165 [==============================] - 5s 30ms/step - loss: 0.2692 - accuracy: 0.9927 - val_loss: 0.4810 - val_accuracy: 0.9509 - lr: 1.0000e-05
# Epoch 93/100
# 165/165 [==============================] - 5s 29ms/step - loss: 0.2682 - accuracy: 0.9928 - val_loss: 0.4803 - val_accuracy: 0.9509 - lr: 1.0000e-05
# Epoch 94/100
# 165/165 [==============================] - 5s 30ms/step - loss: 0.2709 - accuracy: 0.9926 - val_loss: 0.4801 - val_accuracy: 0.9496 - lr: 1.0000e-05
# Epoch 95/100
# 165/165 [==============================] - 5s 31ms/step - loss: 0.2702 - accuracy: 0.9924 - val_loss: 0.4809 - val_accuracy: 0.9504 - lr: 1.0000e-05
# Epoch 96/100
# 165/165 [==============================] - 5s 31ms/step - loss: 0.2699 - accuracy: 0.9919 - val_loss: 0.4813 - val_accuracy: 0.9496 - lr: 1.0000e-05
# Epoch 97/100
# 165/165 [==============================] - 5s 29ms/step - loss: 0.2672 - accuracy: 0.9925 - val_loss: 0.4809 - val_accuracy: 0.9493 - lr: 1.0000e-05
# Epoch 98/100
# 165/165 [==============================] - 5s 31ms/step - loss: 0.2670 - accuracy: 0.9928 - val_loss: 0.4796 - val_accuracy: 0.9504 - lr: 1.0000e-05
# Epoch 99/100
# 165/165 [==============================] - 5s 30ms/step - loss: 0.2667 - accuracy: 0.9927 - val_loss: 0.4798 - val_accuracy: 0.9502 - lr: 1.0000e-05
# Epoch 100/100
# 165/165 [==============================] - 5s 30ms/step - loss: 0.2635 - accuracy: 0.9937 - val_loss: 0.4801 - val_accuracy: 0.9507 - lr: 1.0000e-05
# 141/141 [==============================] - 1s 7ms/step - loss: 0.4801 - accuracy: 0.9507
# Test Accuracy with Enhanced Dense Neural Network and PCA: 0.9506666660308838

# %%
# Retrieve metrics
acc = history.history['accuracy']         # Correct key for training accuracy
val_acc = history.history['val_accuracy'] # Correct key for validation accuracy
loss = history.history['loss']            # Correct key for training loss
val_loss = history.history['val_loss']    # Correct key for validation loss

epochs = range(len(acc))

# Plot training and validation loss
plt.figure(figsize=(12, 6))
plt.plot(epochs, loss, '--', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Plot training and validation accuracy
plt.figure(figsize=(12, 6))
plt.plot(epochs, acc, '--', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# Predict the labels for the test set  # Ensure test_feature is the correct variable
y_pred_prob = model.predict(test_features)
y_pred = np.argmax(y_pred_prob, axis=1)

# Convert test_label from one-hot encoding to class labels
y_true = np.argmax(test_label_one_hot, axis=1)

# Class names
class_names = ['Bacterial Spot', 'Early Blight', 'Healthy', 'Leaf Mold', 'Yellow Leaf Curl Virus']

# Create confusion matrix
conf_matrix = confusion_matrix(y_true, y_pred)

# Plot confusion matrix
plt.figure(figsize=(11, 9))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names, vmin=0)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 141/141 [==============================] - 1s 6ms/step

# %%
model.summary()# Assuming your model has a convolutional layer named 'conv1'
# Accessing the first dense layer
dense_layer = model.get_layer('dense')

# Get details of the dense layer
print("Output Shape:", dense_layer.output_shape)
print("Number of Parameters:", dense_layer.count_params())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1024)              103424
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense_1 (Dense)             (None, 512)               524800
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 256)               131328
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 128)               32896
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_4 (Dense)             (None, 64)                8256
#
#  dropout_4 (Dropout)         (None, 64)                0
#
#  dense_5 (Dense)             (None, 32)                2080
#
#  dropout_5 (Dropout)         (None, 32)                0
#
#  dense_6 (Dense)             (None, 5)                 165
#
# =================================================================
# Total params: 802949 (3.06 MB)
# Trainable params: 802949 (3.06 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Output Shape: (None, 1024)
# Number of Parameters: 103424

# %%
model.save(r"C:\Users\ACER\Pca_model\model0.h5")
